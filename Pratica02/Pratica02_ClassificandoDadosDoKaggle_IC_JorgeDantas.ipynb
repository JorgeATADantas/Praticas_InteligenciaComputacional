# %% [markdown]
# **Prática 2 – Classificando dados do Kaggle**

# %% [markdown]
# **Aluno: Jorge Aliomar Trocoli Abdon Dantas**

# %% [markdown]
# **Objetivo(s):**
#
# Aplicar os algoritmos de classificação [Árvore de Decisão](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html), [Naive Bayes](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB), [kNN](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) e [SVM](https://scikit-learn.org/stable/api/sklearn.svm.html) na resolução de um problema real de predição, por meio da participação na competição "**Santander Customer Transaction Prediction**" no Kaggle. A atividade tem como foco o desenvolvimento prático, a comparação entre modelos e a interpretação crítica dos resultados obtidos.

# %% [markdown]
# Você você estiver com dúvidas em relação ao funcionamento básico de Python, assista os vídeos:
# - https://didatica.tech/curso-de-python-online-para-iniciantes/
# - https://www.youtube.com/watch?v=oUrBHiT-lzo

# %%
#Montar drive para leitura das Bases de Dados
#from google.colab import drive

#drive.mount('/gdrive')
#%cd /gdrive/MyDrive/2025-1_PraticasIC/Pratica02

# %%
#Importando Bibliotecas Pandas
import pandas as pd

# %%
#Carregando Base de dados
df_test = pd.read_csv("test.csv")
df_train = pd.read_csv("train.csv")

# %%
# Visualizando os dados de treino
df_train
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 0       -9.2834  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910
# 1        7.0433  5.6208  16.5338  ...   7.6421   7.7214   2.5837  10.9516
# 2       -9.0837  6.9427  14.6155  ...   2.9057   9.7905   1.6704   1.6858
# 3       -1.8361  5.8428  14.9250  ...   4.4666   4.7433   0.7178   1.4214
# 4        2.4486  5.9405  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942
# ...         ...     ...      ...  ...      ...      ...      ...      ...
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       18.5227  -2.3978   7.8784   8.5635  12.7803  -1.0914
# 1       15.4305   2.0339   8.1267   8.7889  18.3560   1.9518
# 2       21.6042   3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       23.0347  -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       13.2876  -1.5121   3.9267   9.5031  17.9974  -8.8104
# ...         ...      ...      ...      ...      ...      ...
# 199995  18.0249  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199996  22.2717   1.7337  -2.1651   6.7419  15.9054   0.3388
# 199997  23.5311  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199998  20.4158  -0.0786   6.7980  10.0342  15.5289 -13.9001
# 199999  15.2101  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [200000 rows x 202 columns]

# %%
# Visualizando os dados de teste
df_test
# Out:
#             ID_code    var_0    var_1    var_2   var_3    var_4    var_5  \
# 0            test_0  11.0656   7.7798  12.9536  9.4292  11.4327  -2.3805
# 1            test_1   8.5304   1.2543  11.3047  5.1858   9.1974  -4.0117
# 2            test_2   5.4827 -10.3581  10.1407  7.0479  10.2628   9.8052
# 3            test_3   8.5374  -1.3222  12.0220  6.5749   8.8458   3.1744
# 4            test_4  11.7058  -0.1327  14.1295  7.7506   9.1035  -8.5848
# ...             ...      ...      ...      ...     ...      ...      ...
# 199995  test_199995  13.1678   1.0136  10.4333  6.7997   8.5974  -4.1641
# 199996  test_199996   9.7171  -9.1462   7.3443  9.1421  12.8936   3.0191
# 199997  test_199997  11.6360   2.2769  11.2074  7.7649  12.6796  11.3224
# 199998  test_199998  13.5745  -0.5134  13.6584  7.4855  11.2241 -11.3037
# 199999  test_199999  10.4664   1.8070  10.2277  6.0654  10.0258   1.0789
#
#          var_6    var_7   var_8  ...  var_190  var_191  var_192  var_193  \
# 0       5.8493  18.2675  2.1337  ...  -2.1556  11.8495  -1.4300   2.4508
# 1       6.0196  18.6316 -4.4131  ...  10.6165   8.8349   0.9403  10.1282
# 2       4.8950  20.2537  1.5233  ...  -0.7484  10.9935   1.9803   2.1800
# 3       4.9397  20.5660  3.3755  ...   9.5702   9.0766   1.6580   3.5813
# 4       6.8595  10.6048  2.9890  ...   4.2259   9.1723   1.2835   3.3778
# ...        ...      ...     ...  ...      ...      ...      ...      ...
# 199995  4.8579  14.7625 -2.7239  ...   2.0544   9.6849   4.6734  -1.3660
# 199996  5.6888  18.8862  5.0915  ...   5.0071   6.6548   1.8197   2.4104
# 199997  5.3883  18.3794  1.6603  ...   5.1536   2.6498   2.4937  -0.0637
# 199998  4.1959  16.8280  5.3208  ...   3.4259   8.5012   2.2713   5.7621
# 199999  4.8879  14.4892 -0.5902  ...   0.1398   9.2828   1.3601   4.8985
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       13.7112   2.4669   4.3654  10.7200  15.4722  -8.7197
# 1       15.5765   0.4773  -1.4852   9.8714  19.1293 -20.9760
# 2       12.9813   2.1281  -7.1086   7.0618  19.8956 -23.1794
# 3       15.1874   3.1656   3.9567   9.2295  13.0168  -4.2108
# 4       19.5542  -0.2860  -5.1612   7.2882  13.9260  -9.1846
# ...         ...      ...      ...      ...      ...      ...
# 199995  12.8721   1.2013  -4.6195   9.1568  18.2102   4.8801
# 199996  18.9037  -0.9337   2.9995   9.1112  18.1740 -20.7689
# 199997  20.0609  -1.1742  -4.1524   9.1933  11.7905 -22.2762
# 199998  17.0056   1.1763  -2.3761   8.1079   8.7735  -0.2122
# 199999  20.0926  -1.3048  -2.5981  10.3378  14.3340  -7.7094
#
# [200000 rows x 201 columns]

# %%
# Separar atributos e classe
X_train = df_train.drop(columns=["ID_code", "target"])  #remove as colunas ID_code e target
y_train = df_train["target"]                            #iremos tentar prever a coluna target

# %%
#Removendo o atributo `ID_code`, porque essa coluna não trará informação para a classificação
X_test = df_test.drop(columns=["ID_code"])
X_test
# Out:
#           var_0    var_1    var_2   var_3    var_4    var_5   var_6    var_7  \
# 0       11.0656   7.7798  12.9536  9.4292  11.4327  -2.3805  5.8493  18.2675
# 1        8.5304   1.2543  11.3047  5.1858   9.1974  -4.0117  6.0196  18.6316
# 2        5.4827 -10.3581  10.1407  7.0479  10.2628   9.8052  4.8950  20.2537
# 3        8.5374  -1.3222  12.0220  6.5749   8.8458   3.1744  4.9397  20.5660
# 4       11.7058  -0.1327  14.1295  7.7506   9.1035  -8.5848  6.8595  10.6048
# ...         ...      ...      ...     ...      ...      ...     ...      ...
# 199995  13.1678   1.0136  10.4333  6.7997   8.5974  -4.1641  4.8579  14.7625
# 199996   9.7171  -9.1462   7.3443  9.1421  12.8936   3.0191  5.6888  18.8862
# 199997  11.6360   2.2769  11.2074  7.7649  12.6796  11.3224  5.3883  18.3794
# 199998  13.5745  -0.5134  13.6584  7.4855  11.2241 -11.3037  4.1959  16.8280
# 199999  10.4664   1.8070  10.2277  6.0654  10.0258   1.0789  4.8879  14.4892
#
#          var_8   var_9  ...  var_190  var_191  var_192  var_193  var_194  \
# 0       2.1337  8.8100  ...  -2.1556  11.8495  -1.4300   2.4508  13.7112
# 1      -4.4131  5.9739  ...  10.6165   8.8349   0.9403  10.1282  15.5765
# 2       1.5233  8.3442  ...  -0.7484  10.9935   1.9803   2.1800  12.9813
# 3       3.3755  7.4578  ...   9.5702   9.0766   1.6580   3.5813  15.1874
# 4       2.9890  7.1437  ...   4.2259   9.1723   1.2835   3.3778  19.5542
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 199995 -2.7239  6.9937  ...   2.0544   9.6849   4.6734  -1.3660  12.8721
# 199996  5.0915  6.3545  ...   5.0071   6.6548   1.8197   2.4104  18.9037
# 199997  1.6603  5.7341  ...   5.1536   2.6498   2.4937  -0.0637  20.0609
# 199998  5.3208  8.9032  ...   3.4259   8.5012   2.2713   5.7621  17.0056
# 199999 -0.5902  7.8362  ...   0.1398   9.2828   1.3601   4.8985  20.0926
#
#         var_195  var_196  var_197  var_198  var_199
# 0        2.4669   4.3654  10.7200  15.4722  -8.7197
# 1        0.4773  -1.4852   9.8714  19.1293 -20.9760
# 2        2.1281  -7.1086   7.0618  19.8956 -23.1794
# 3        3.1656   3.9567   9.2295  13.0168  -4.2108
# 4       -0.2860  -5.1612   7.2882  13.9260  -9.1846
# ...         ...      ...      ...      ...      ...
# 199995   1.2013  -4.6195   9.1568  18.2102   4.8801
# 199996  -0.9337   2.9995   9.1112  18.1740 -20.7689
# 199997  -1.1742  -4.1524   9.1933  11.7905 -22.2762
# 199998   1.1763  -2.3761   8.1079   8.7735  -0.2122
# 199999  -1.3048  -2.5981  10.3378  14.3340  -7.7094
#
# [200000 rows x 200 columns]

# %% [markdown]
# #TREINAMENTO E PREDIÇÃO - Árvore de Decisão

# %% [markdown]
# ##NÃO AJUSTADO

# %%
#Importando o Classificador
from sklearn.tree import DecisionTreeClassifier

# %%
# Normalização
# Para o classificador Árvore de Decisão a Normalização não faz diferença

# Importanto Biblioteca do Normalizador Padrão
#from sklearn.preprocessing   import StandardScaler;

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = DecisionTreeClassifier(random_state=42,max_depth=3)

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.8977

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_ArvoreDecisao_NãoAjustado.csv", index=False)

# %% [markdown]
# ##AJUSTADO

# %%
#Importando o Classificador
from sklearn.tree import DecisionTreeClassifier

# %%
# Normalização
# Para o classificador Árvore de Decisão a Normalização não faz diferença

# Importanto Biblioteca do Normalizador Padrão
#from sklearn.preprocessing   import StandardScaler;

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
#Hiperparâmetro ajustado = max_depth = 30
classifier = DecisionTreeClassifier(random_state=42,max_depth=30)

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# DecisionTreeClassifier(max_depth=30, random_state=42)

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.8537833333333333

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_ArvoreDecisao_Ajustado.csv", index=False)

# %% [markdown]
# #TREINAMENTO E PREDIÇÃO - Naive Bayes

# %% [markdown]
# ##NÃO AJUSTADO

# %%
#Importando o Classificador
from sklearn.naive_bayes import GaussianNB

# %%
# Normalização
# Para o classificador Naive Bayes a Normalização não faz diferença

# Importanto Biblioteca do Normalizador Padrão
#from sklearn.preprocessing   import StandardScaler;

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = GaussianNB()

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# GaussianNB()

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.9206666666666666

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_NaiveBayes_NãoAjustado.csv", index=False)

# %% [markdown]
# ##AJUSTADO

# %%
#Importando o Classificador
from sklearn.naive_bayes import GaussianNB

# %%
# Normalização
# Para o classificador Naive Bayes a Normalização não faz diferença

# Importanto Biblioteca do Normalizador Padrão
#from sklearn.preprocessing   import StandardScaler;

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
#Hiperparâmetro ajustado: var_smoothing=1e-7
classifier = GaussianNB(var_smoothing=1e-7)

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# GaussianNB(var_smoothing=1e-07)

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.92055

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_NaiveBayes_Ajustado.csv", index=False)

# %% [markdown]
# #TREINAMENTO E PREDIÇÃO - kNN

# %% [markdown]
# ##NÃO AJUSTADO

# %%
#Importando o Classificador
from sklearn.neighbors import KNeighborsClassifier

# %%
# Normalização
# Para o classificador kNN a Normalização faz diferença

# Importanto Biblioteca do Normalizador Padrão
from sklearn.preprocessing   import StandardScaler;

scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train_Scaled, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = KNeighborsClassifier()

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# KNeighborsClassifier()

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.8975666666666666

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)
# Out:
# C:\Users\jorge\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_kNN_NãoAjustado.csv", index=False)

# %% [markdown]
# ##AJUSTADO

# %%
#Importando o Classificador
from sklearn.neighbors import KNeighborsClassifier

# %%
# Normalização
# Para o classificador kNN a Normalização faz diferença

# Importanto Biblioteca do Normalizador Padrão
from sklearn.preprocessing   import StandardScaler;

scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train_Scaled, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = KNeighborsClassifier(n_neighbors = 5,        #Número de Vizinhos
                                  weights = "distance",   #Peso/Ponderação dado pela distância dos vizinhos
                                  metric='euclidean')     #Distância euclidiana

# %%
  #Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# KNeighborsClassifier(metric='euclidean', weights='distance')

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.8975666666666666

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)
# Out:
# C:\Users\jorge\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_kNN_Ajustado.csv", index=False)

# %% [markdown]
# #TREINAMENTO E PREDIÇÃO - SVM

# %% [markdown]
# ##NÃO AJUSTADO

# %%
#Importando o Classificador
from sklearn.svm import SVC

# %%
# Normalização
# Para o classificador kNN a Normalização faz diferença

# Importanto Biblioteca do Normalizador Padrão
from sklearn.preprocessing   import StandardScaler;

scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train_Scaled, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = SVC(random_state=42)

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# SVC(random_state=42)

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.91475

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)
# Out:
# C:\Users\jorge\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       1
# 1            test_1       1
# 2            test_2       1
# 3            test_3       1
# 4            test_4       1
# ...             ...     ...
# 199995  test_199995       1
# 199996  test_199996       1
# 199997  test_199997       1
# 199998  test_199998       1
# 199999  test_199999       1
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_SVM_NãoAjustado.csv", index=False)

# %% [markdown]
# ##AJUSTADO

# %%
#Importando o Classificador
from sklearn.svm import SVC

# %%
# Normalização
# Para o classificador kNN a Normalização faz diferença

# Importanto Biblioteca do Normalizador Padrão
from sklearn.preprocessing   import StandardScaler;

scaler = StandardScaler()
X_train_Scaled = scaler.fit_transform(X_train)

# %%
#Importando biblioteca train_test_split
from sklearn.model_selection import train_test_split; # train_test_split do sklearn

# Divisão treino/teste
X_train_local, X_test_local, y_train_local, y_test_local = train_test_split(X_train_Scaled, y_train, test_size = 0.3, random_state = 42)

# %%
#Instanciamento do classificador
classifier = SVC(random_state=42,   #seed randômica
                 C =3.0,            #sensibilidade da margem
                 degree = 3,        #grau do polinômio
                 kernel = 'poly')   #tipo de ajuste

# %%
#Treinamento do Classificador
classifier.fit(X_train_local, y_train_local)
# Out:
# SVC(C=3.0, kernel='poly', random_state=42)

# %%
#Predição do Modelo Local
y_pred_local = classifier.predict(X_test_local)

# %%
#Determinação da Acuracia

#Importando Biblioteca de Métricas - Acurácia
from sklearn.metrics import accuracy_score

#Calculo do accuracy_score
acc = accuracy_score(y_test_local,y_pred_local)
acc
# Out:
# 0.90805

# %%
#Predição do Modelo com os dados de Teste Global
predictions = classifier.predict(X_test)
# Out:
# C:\Users\jorge\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
#Geração do Data Frame das predições com o Teste Global
df_test["target"] = predictions

# %%
#Exibição do Data Frame que será enviado para o Kaggle
df_test[["ID_code","target"]]
# Out:
#             ID_code  target
# 0            test_0       0
# 1            test_1       0
# 2            test_2       0
# 3            test_3       0
# 4            test_4       0
# ...             ...     ...
# 199995  test_199995       0
# 199996  test_199996       0
# 199997  test_199997       0
# 199998  test_199998       0
# 199999  test_199999       0
#
# [200000 rows x 2 columns]

# %%
#Salvar o Data Frame que será enviado ao Kaggle em um arquivo .CSV
df_test[["ID_code","target"]].to_csv("solucao-2025_SVM_Ajustado.csv", index=False)

# %% [markdown]
# #RESULTADOS

# %% [markdown]
# Após a realização das simulações e geração dos arquivos para submissão mo Kaggle,obteve-se os seguintes resultados após submissão

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Consolidando os resultados de todas as acucárias encontradas chegou-se aos resultados mostrados na tabela abaixo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Observa-se me tabela que todos os resultados após submissão ao Kaggle foram inferiores aos encontrados na avaliação local. Exceto o classificador Naive Bayes, todos os demais ficaram com acurácia entre 0,5000 e 0,5607. Supõe-se que nos modelos locais houve um overfitting com aqueles dados (todos acima de 0,85), de modo que, ao realizar a submissão no Kaggle a modelagem se mostrou inadequada. Os 2 melhores modelos locais foram o Naive Bayes (0,9206) e SVM (0,9081). Enquanto o melhor modelo no Kaggle foi o Naive Bayes (0,68).
